# %%
#### uso di CSV

import csv

# scrittura csv
with open('accounts.csv', mode='w', newline='') as accounts:
    writer = csv.writer(accounts)
    writer.writerow([100, 'Jones', 24.98])
    writer.writerow([200, 'Doe', 345.67])
    writer.writerow([300, 'White', 0.00])
    writer.writerow([400, 'Stone', -42.16])
    writer.writerow([500, 'Rich', 224.62])

# lettura csv
with open('accounts.csv', 'r', newline='') as accounts:
    print(f'{"Account":<10}{"Name":<10}{"Balance":>10}')
    reader = csv.reader(accounts)
    for record in reader:
        account, name, balance = record
        print(f'{account:<10}{name:<10}{balance:>10}')
# Out:
# Account   Name         Balance
# 100       Jones          24.98
# 200       Doe           345.67
# 300       White            0.0
# 400       Stone         -42.16
# 500       Rich          224.62

# %%
### Esempio di analisi del dataset Titanic

import pandas as pd
titanic = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/carData/TitanicSurvival.csv')

# %%
titanic.head()
# Out:
#                         Unnamed: 0 survived     sex      age passengerClass
# 0    Allen, Miss. Elisabeth Walton      yes  female  29.0000            1st
# 1   Allison, Master. Hudson Trevor      yes    male   0.9167            1st
# 2     Allison, Miss. Helen Loraine       no  female   2.0000            1st
# 3  Allison, Mr. Hudson Joshua Crei       no    male  30.0000            1st
# 4  Allison, Mrs. Hudson J C (Bessi       no  female  25.0000            1st

# %%
titanic.tail()
# Out:
#                      Unnamed: 0 survived     sex   age passengerClass
# 1304       Zabour, Miss. Hileni       no  female  14.5            3rd
# 1305      Zabour, Miss. Thamine       no  female   NaN            3rd
# 1306  Zakarian, Mr. Mapriededer       no    male  26.5            3rd
# 1307        Zakarian, Mr. Ortin       no    male  27.0            3rd
# 1308         Zimmerman, Mr. Leo       no    male  29.0            3rd

# %%
titanic.describe() ## analisi dei dati solo su colonne numeriche, i.e., age
# notare che il count è inferiore a 1308, perchè? ho diversi valori missing, trattati come NaN che non
# sono considerati nel calcolo delle statistiche by default in pandas
# Out:
#                age
# count  1046.000000
# mean     29.881135
# std      14.413500
# min       0.166700
# 25%      21.000000
# 50%      28.000000
# 75%      39.000000
# max      80.000000

# %%
### otteniamo statistiche solo per i sopravvisuti
"""
    in particolare:
        - count indica quanti elementi hanno il campo survived == yes
        - unique indica quanti valori unici assume il campo survived (yes or no)
        - top è il valore più frequente, cioè titanic.survived == 'no'...purtroppo
        - freq indica il numero di occorrenze per il predicato titanic.survived == 'yes'
"""
(titanic.survived == 'yes').describe()
# Out:
# count      1309
# unique        2
# top       False
# freq        809
# Name: survived, dtype: object

# %%
### analizziamo i dati del dataset titanic in maniera grafica

"""
    otteniamo l'istogramma tramite hist (definito in matplotlib) sul dataset titanic
    notare che otteniamo l'istogramma solo per le colonne numeriche
"""
# %matplotlib 
#abilitiamo matplotlib backend, se disattiviamo questo usiamo quello built-in in jupiter

histogram = titanic.hist()
